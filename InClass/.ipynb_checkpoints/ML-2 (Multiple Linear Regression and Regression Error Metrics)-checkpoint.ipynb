# %% [markdown]
# ## Multiple Linear Regression and Regression Error Metrics

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Import library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
plt.rcParams["figure.figsize"] = (10,6)
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read Dataset

# %%
df = pd.read_csv("Advertising.csv")
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# ## Data Preparation

# %%
df.shape
# Out:
# (200, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
print(np.mean([100, 110, 120, 115]))
print(np.std([100, 110, 120, 115]))
# Out:
# 111.25
# 7.39509972887452

# %%
print(np.mean([100, 110, 120, 700]))
print(np.std([100, 110, 120, 700]))
# Out:
# 257.5
# 255.57533136044253

# %%
print(np.mean([100, 110, 120, 900]))
print(np.std([100, 110, 120, 900]))
# Out:
# 307.5
# 342.153109002388

# %% [markdown]
# ## Distribution of features

# %%
sns.pairplot(df);

# %%
df.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Train-Test Split

# %%
# pip install scikit-learn

# %%
X = df.drop(columns ="sales") #df[["TV", "radio", "newspaper"]]
y = df["sales"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state =42)

# %%
df.sample(15)
# Out:
#         TV  radio  newspaper  sales
# 42   293.6   27.7        1.8   20.7
# 54   262.7   28.8       15.9   20.2
# 43   206.9    8.4       26.4   12.9
# 118  125.7   36.9       79.2   15.9
# 167  206.8    5.2       19.4   12.2
# 41   177.0   33.4       38.7   17.1
# 45   175.1   22.5       31.5   14.9
# 66    31.5   24.6        2.2    9.5
# 105  137.9   46.4       59.0   19.2
# 172   19.6   20.1       17.0    7.6
# 154  187.8   21.1        9.5   15.6
# 177  170.2    7.8       35.2   11.7
# 119   19.4   16.0       22.3    6.6
# 146  240.1    7.3        8.7   13.2
# 7    120.2   19.6       11.6   13.2

# %%
print("Train features shape : ", X_train.shape)
print("Train target shape   : ", y_train.shape)
print("Test features shape  : ", X_test.shape)
print("Test target shape    : ", y_test.shape)
# Out:
# Train features shape :  (120, 3)
# Train target shape   :  (120,)
# Test features shape  :  (80, 3)
# Test target shape    :  (80,)

# %%
X_train
# Out:
#         TV  radio  newspaper
# 2     17.2   45.9       69.3
# 77   120.5   28.5       14.2
# 46    89.7    9.9       35.7
# 187  191.1   28.7       18.2
# 191   75.5   10.8        6.0
# ..     ...    ...        ...
# 106   25.0   11.0       29.7
# 14   204.1   32.9       46.0
# 92   217.7   33.5       59.0
# 179  165.6   10.0       17.6
# 102  280.2   10.1       21.4
#
# [120 rows x 3 columns]

# %%
X_test
# Out:
#         TV  radio  newspaper
# 95   163.3   31.6       52.9
# 15   195.4   47.7       52.9
# 30   292.9   28.3       43.2
# 158   11.7   36.9       45.2
# 128  220.3   49.0        3.2
# ..     ...    ...        ...
# 113  209.6   20.6       10.7
# 26   142.9   29.3       12.6
# 139  184.9   43.9        1.7
# 100  222.4    4.3       49.8
# 111  241.7   38.0       23.2
#
# [80 rows x 3 columns]

# %%
y_train
# Out:
# 2       9.3
# 77     14.2
# 46     10.6
# 187    17.3
# 191     9.9
#        ...
# 106     7.2
# 14     19.0
# 92     19.4
# 179    12.6
# 102    14.8
# Name: sales, Length: 120, dtype: float64

# %% [markdown]
# ## Model Fitting and Compare Actual and Predicted Labels

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([16.63902413, 21.27548678, 21.72174077, 10.8164995 , 22.22714832,
#        13.35087848, 21.26296358,  7.28718173, 13.35732452, 15.18037868,
#         8.89761565,  6.49138646, 14.51326935,  8.83867006,  9.49159091,
#        12.07490644,  8.84018706, 16.20182611, 10.27027547, 18.79536766,
#        19.93298024, 13.8642087 , 12.38785643, 21.71127111,  7.53457962,
#         5.56500602, 20.99254849, 11.80311964,  9.06161794,  8.37526001,
#        12.25279138,  9.91469854, 21.830671  , 12.77700019, 18.26337691,
#        20.13197086, 14.15091605, 21.11947555, 10.80927512,  4.31197375,
#         9.51753508, 12.4319186 , 10.11635773,  8.0371654 , 13.2521022 ,
#         5.15028895,  9.27682376, 14.10374127,  8.70521481, 11.60297218,
#        15.67617324, 11.6638007 , 13.31758548, 11.08435278,  6.29895342,
#         9.7925166 ,  9.3626635 , 24.42448277,  7.59664858, 12.20187455,
#        17.5088018 , 15.24169083, 11.4355623 , 11.17957067, 16.52433204,
#         6.81935356, 21.28044036,  6.02341036,  9.66588589, 11.55078487,
#         9.02737167,  6.26302446, 14.85416637, 17.49017722, 16.22677507,
#        16.17507516, 14.92216334, 19.61246915, 13.84944178, 21.17629165])

# %%
model.coef_
# Out:
# array([0.04491068, 0.19843664, 0.0085429 ])

# %%
model.intercept_
# Out:
# 2.58259357256755

# %%
# y_pred = b1 * TV + b2 * radio + b3 * newspaper + b0

# %%
sum(X_test.loc[95] * model.coef_) + model.intercept_
# Out:
# 16.639024125217446

# %%
my_dict = {"Actual": y_test, "Pred": y_pred, "Residual":y_test-y_pred}

# %%
comparing = pd.DataFrame(my_dict)
comparing
# Out:
#      Actual       Pred  Residual
# 95     16.9  16.639024  0.260976
# 15     22.4  21.275487  1.124513
# 30     21.4  21.721741 -0.321741
# 158     7.3  10.816499 -3.516499
# 128    24.7  22.227148  2.472852
# ..      ...        ...       ...
# 113    15.9  16.175075 -0.275075
# 26     15.0  14.922163  0.077837
# 139    20.7  19.612469  1.087531
# 100    11.7  13.849442 -2.149442
# 111    21.8  21.176292  0.623708
#
# [80 rows x 3 columns]

# %%
sum(comparing["Residual"])
# Out:
# -8.264279338412436

# %%
result_sample = comparing.head(25)
result_sample
# Out:
#      Actual       Pred  Residual
# 95     16.9  16.639024  0.260976
# 15     22.4  21.275487  1.124513
# 30     21.4  21.721741 -0.321741
# 158     7.3  10.816499 -3.516499
# 128    24.7  22.227148  2.472852
# 115    12.6  13.350878 -0.750878
# 69     22.3  21.262964  1.037036
# 170     8.4   7.287182  1.112818
# 174    11.5  13.357325 -1.857325
# 45     14.9  15.180379 -0.280379
# 66      9.5   8.897616  0.602384
# 182     8.7   6.491386  2.208614
# 165    11.9  14.513269 -2.613269
# 78      5.3   8.838670 -3.538670
# 186    10.3   9.491591  0.808409
# 177    11.7  12.074906 -0.374906
# 56      5.5   8.840187 -3.340187
# 152    16.6  16.201826  0.398174
# 82     11.3  10.270275  1.029725
# 68     18.9  18.795368  0.104632
# 124    19.7  19.932980 -0.232980
# 16     12.5  13.864209 -1.364209
# 148    10.9  12.387856 -1.487856
# 93     22.2  21.711271  0.488729
# 65      9.3   7.534580  1.765420

# %%
result_sample.Residual.sum()
# Out:
# -6.264617733546099

# %%
result_sample.plot(kind ="bar", figsize=(15,9))
plt.show()

# %% [markdown]
# ## Error Metrics

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
R2_score = r2_score(y_test, y_pred)
R2_score
# Out:
# 0.864341606388241

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 1.4259694785966046

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 3.4290064802196296

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
rmse
# Out:
# 1.8517576731904284

# %% [markdown]
# mae ve rmse birbilerine yakin olmasi hatalarin buyuk olmadigini gosterir

# %%
sales_mean = df["sales"].mean()
sales_mean
# Out:
# 14.022500000000003

# %%
mae / sales_mean # mean absolute percentage error
# Out:
# 0.10169152994092383

# %%
rmse / sales_mean
# Out:
# 0.13205617209416495

# %% [markdown]
# ## Adjusted R2 score
#
# https://towardsdatascience.com/demystifying-r-squared-and-adjusted-r-squared-52903c006a60

# %%
def adj_r2(y_test, y_pred, df):
    r2 = r2_score(y_test, y_pred)
    n = df.shape[0]   # number of observations
    p = df.shape[1]-1 # number of independent variables 
    adj_r2 = 1 - (1-r2)*(n-1)/(n-p-1)
    return adj_r2

# %%
adj_r2(y_test, y_pred, df)
# Out:
# 0.8622652024043875

# %% [markdown]
# ## What is the concept of punishment for RMSE error metric?

# %%
variables = {"Actual": [1000, 2000, 3000, 4000, 5000], "pred": [1100, 2200, 3200, 4200, 5500]}

# %%
df_2 = pd.DataFrame(variables)
df_2
# Out:
#    Actual  pred
# 0    1000  1100
# 1    2000  2200
# 2    3000  3200
# 3    4000  4200
# 4    5000  5500

# %%
df_2["residual"] = abs(df_2.Actual - df_2.pred)

# %%
df_2
# Out:
#    Actual  pred  residual
# 0    1000  1100       100
# 1    2000  2200       200
# 2    3000  3200       200
# 3    4000  4200       200
# 4    5000  5500       500

# %%
#mae
df_2.residual.sum()/5 #200
# Out:
# 240.0

# %%
#rmse
((df_2.residual**2).sum()/5)**0.5 #209.76
# Out:
# 275.68097504180446

# %% [markdown]
# ## Evaluation Model

# %%
def eval_metric(actual, pred):
    mae = mean_absolute_error(actual, pred)
    mse = mean_squared_error(actual, pred)
    rmse = np.sqrt(mean_squared_error(actual, pred))
    R2_score = r2_score(actual, pred)
    print("Model testing performance:")
    print("--------------------------")
    print(f"R2_score \t: {R2_score}")
    print(f"MAE \t\t: {mae}")
    print(f"MSE \t\t: {mse}")
    print(f"RMSE \t\t: {rmse}")

# %%
eval_metric(y_test, y_pred)
# Out:
# Model testing performance:
# --------------------------
# R2_score 	: 0.864341606388241
# MAE 		: 1.4259694785966046
# MSE 		: 3.4290064802196296
# RMSE 		: 1.8517576731904284

# %%
y_train_pred = model.predict(X_train)

# %%
eval_metric(y_train, y_train_pred)
# Out:
# Model testing performance:
# --------------------------
# R2_score 	: 0.9082575436146726
# MAE 		: 1.1598226917244128
# MSE 		: 2.5052418373329317
# RMSE 		: 1.5827955766089732

# %% [markdown]
# ## Is data suitable for linear regression?
#
# https://stats.stackexchange.com/questions/12262/what-if-residuals-are-normally-distributed-but-y-is-not

# %% [markdown]
# ## Plotting residuals

# %%
residuals = y_test-y_pred

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(x = y_test, y = residuals) #-residuals
plt.axhline(y = 0, color ="r", linestyle = "--")
plt.ylabel("residuals")
plt.show()

# %%
sns.kdeplot(residuals)
# Out:
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %%
#pip install yellowbrick

# %%
from yellowbrick.regressor import ResidualsPlot

# Instantiate the linear model and visualizer
model = LinearRegression()
visualizer = ResidualsPlot(model)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show();        # Finalize and render the figure

# %% [markdown]
# ## Prediction Error for LinearRegression

# %%
from yellowbrick.regressor import PredictionError
# Instantiate the linear model and visualizer
model = LinearRegression()
visualizer = PredictionError(model)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show();

# %% [markdown]
# ## Retraining Model on Full Data

# %%
final_model = LinearRegression()

# %%
final_model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Coefficients

# %%
final_model.coef_
# Out:
# array([ 0.04576465,  0.18853002, -0.00103749])

# %%
final_model.intercept_
# Out:
# 2.9388893694594085

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
coeff_df = pd.DataFrame(final_model.coef_, index = X.columns, columns = ["Coefficient"] )

# %%
coeff_df
# Out:
#            Coefficient
# TV            0.045765
# radio         0.188530
# newspaper    -0.001037

# %% [markdown]
# ## Prediction on New Data

# %%
adv = [[150, 20, 15]]

# %%
adv
# Out:
# [[150, 20, 15]]

# %%
final_model.predict(adv)
# Out:
# array([13.55862413])

# %%
final_model.coef_
# Out:
# array([ 0.04576465,  0.18853002, -0.00103749])

# %%
final_model.intercept_
# Out:
# 2.9388893694594085

# %%
sum(final_model.coef_ * [150, 20, 15]) + final_model.intercept_
# Out:
# 13.558624130495996

# %%
adv_2 = [[150, 20, 15], [160, 20, 15]]

# %%
final_model.predict(adv_2)
# Out:
# array([13.55862413, 14.01627059])

# %%
14.01627059 - 13.55862413
# Out:
# 0.4576464599999994

# %% [markdown]
# ## The effect of features on the predicted label

# %%
coeff_df
# Out:
#            Coefficient
# TV            0.045765
# radio         0.188530
# newspaper    -0.001037

# %%
coeff_df.Coefficient * adv[0]
# Out:
# TV           6.864697
# radio        3.770600
# newspaper   -0.015562
# Name: Coefficient, dtype: float64

# %%
6.864697 / 13.55862413
# Out:
# 0.5062974630892729

# %%
3.770600 / 13.55862413
# Out:
# 0.2780960637191142

# %%
-0.015562 / 13.55862413
# Out:
# -0.0011477565755043907
