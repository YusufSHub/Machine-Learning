# %% [markdown]
# # Hierarchical Clustering

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
#%matplotlib notebook
plt.rcParams["figure.figsize"] = (10,6)
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")
#pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df = pd.read_csv("iris.csv")

# %%
import matplotlib.image as mpimg
image = mpimg.imread('iris.png')
plt.figure(figsize = (20,8))
plt.imshow(image)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Exploratory Data Analysis and Visualization

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.pairplot(df);

# %% [markdown]
# ## Scaling Data

# %% [markdown]
# **The K-means algorithm definitely needs scaling**. However, if all our features are in the same/similar range, **there is no need to scale the data**. For these data, scaling may cause worse results in some cases. You should try data both with and without scale and continue with whichever one has good results.

# %% [markdown]
# ## Hopkins Test

# %% [markdown]
# - Hopkins test, a statistical test for randomness of a variable.
# - Null Hypothesis (Ho) : Data points are generated by non-random, uniform distribution (implying no meaningful clusters)
# - Alternate Hypothesis (Ha): Data points are generated by random data points (presence of clusters)
# - The more close 0, the more available to separate clusters

# %%
#!pip install pyclustertend
# Out:
# Collecting pyclustertend
#   Using cached pyclustertend-1.7.0-py3-none-any.whl (7.2 kB)
# Collecting numba<0.55.0,>=0.54.1
#   Using cached numba-0.54.1-cp39-cp39-win_amd64.whl (2.3 MB)
# Requirement already satisfied: pandas<2.0.0,>=1.2.0 in c:\users\44778\anaconda3\lib\site-packages (from pyclustertend) (1.4.2)
# Requirement already satisfied: matplotlib<4.0.0,>=3.3.3 in c:\users\44778\anaconda3\lib\site-packages (from pyclustertend) (3.5.1)
# Collecting numpy==1.20.3
#   Using cached numpy-1.20.3-cp39-cp39-win_amd64.whl (13.7 MB)
# Collecting scikit-learn<0.25.0,>=0.24.0
#   Using cached scikit_learn-0.24.2-cp39-cp39-win_amd64.whl (6.9 MB)
# Requirement already satisfied: cycler>=0.10 in c:\users\44778\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.3.3->pyclustertend) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\44778\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.3.3->pyclustertend) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\44778\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.3.3->pyclustertend) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\44778\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.3.3->pyclustertend) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\44778\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.3.3->pyclustertend) (4.29.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\44778\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.3.3->pyclustertend) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\44778\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.3.3->pyclustertend) (3.0.4)
# Requirement already satisfied: setuptools in c:\users\44778\anaconda3\lib\site-packages (from numba<0.55.0,>=0.54.1->pyclustertend) (61.2.0)
# Collecting llvmlite<0.38,>=0.37.0rc1
#   Using cached llvmlite-0.37.0-cp39-cp39-win_amd64.whl (17.0 MB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\44778\anaconda3\lib\site-packages (from pandas<2.0.0,>=1.2.0->pyclustertend) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\44778\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.3.3->pyclustertend) (1.16.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\44778\anaconda3\lib\site-packages (from scikit-learn<0.25.0,>=0.24.0->pyclustertend) (1.8.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\44778\anaconda3\lib\site-packages (from scikit-learn<0.25.0,>=0.24.0->pyclustertend) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\44778\anaconda3\lib\site-packages (from scikit-learn<0.25.0,>=0.24.0->pyclustertend) (2.2.0)
# Installing collected packages: numpy, llvmlite, scikit-learn, numba, pyclustertend
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.2
#     Uninstalling numpy-1.22.2:
#       Successfully uninstalled numpy-1.22.2
#   Rolling back uninstall of numpy
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy-1.22.2.dist-info\
#    from C:\Users\44778\anaconda3\Lib\site-packages\~umpy-1.22.2.dist-info
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\.libs\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\~libs
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\__config__.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\__config__.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\__init__.cython-30.pxd
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\__init__.cython-30.pxd
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\__init__.pxd
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\__init__.pxd
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\__init__.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\__init__.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\__init__.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\__init__.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\__pycache__\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\~_pycache__
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\_distributor_init.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\_distributor_init.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\_globals.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\_globals.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\_pytesttester.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\_pytesttester.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\_pytesttester.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\_pytesttester.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\_version.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\_version.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\array_api\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\~rray_api
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\compat\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\~ompat
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\conftest.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\conftest.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__init__.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__init__.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__init__.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__init__.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\_add_newdocs.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\_add_newdocs.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\_add_newdocs_scalars.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\_add_newdocs_scalars.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\_asarray.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\_asarray.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\_dtype.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\_dtype.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\_dtype_ctypes.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\_dtype_ctypes.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\_exceptions.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\_exceptions.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\_internal.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\_internal.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\_machar.cpython-38.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\_machar.cpython-38.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\_methods.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\_methods.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\_string_helpers.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\_string_helpers.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\_type_aliases.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\_type_aliases.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\_ufunc_config.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\_ufunc_config.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\arrayprint.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\arrayprint.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\cversions.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\cversions.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\defchararray.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\defchararray.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\einsumfunc.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\einsumfunc.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\fromnumeric.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\fromnumeric.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\function_base.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\function_base.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\generate_numpy_api.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\generate_numpy_api.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\getlimits.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\getlimits.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\memmap.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\memmap.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\multiarray.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\multiarray.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\numeric.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\numeric.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\numerictypes.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\numerictypes.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\overrides.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\overrides.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\records.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\records.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\setup.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\setup.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\setup_common.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\setup_common.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\shape_base.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\shape_base.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\umath.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\umath.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\__pycache__\umath_tests.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\__pycache__\umath_tests.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\_add_newdocs.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\_add_newdocs.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\_add_newdocs_scalars.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\_add_newdocs_scalars.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\_asarray.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\_asarray.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\_asarray.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\_asarray.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\_dtype.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\_dtype.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\_dtype_ctypes.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\_dtype_ctypes.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\_exceptions.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\_exceptions.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\_internal.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\_internal.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\_internal.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\_internal.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\_machar.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\_machar.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\_methods.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\_methods.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\_string_helpers.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\_string_helpers.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\_type_aliases.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\_type_aliases.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\_type_aliases.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\_type_aliases.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\_ufunc_config.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\_ufunc_config.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\_ufunc_config.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\_ufunc_config.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\arrayprint.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\arrayprint.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\arrayprint.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\arrayprint.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\cversions.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\cversions.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\defchararray.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\defchararray.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\defchararray.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\defchararray.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\einsumfunc.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\einsumfunc.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\einsumfunc.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\einsumfunc.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\fromnumeric.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\fromnumeric.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\fromnumeric.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\fromnumeric.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\function_base.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\function_base.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\function_base.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\function_base.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\generate_numpy_api.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\generate_numpy_api.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\getlimits.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\getlimits.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\getlimits.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\getlimits.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\include\numpy\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\core\include\~umpy
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\lib\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\core\~ib
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\memmap.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\memmap.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\memmap.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\memmap.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\multiarray.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\multiarray.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\multiarray.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\multiarray.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\numeric.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\numeric.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\numeric.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\numeric.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\numerictypes.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\numerictypes.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\numerictypes.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\numerictypes.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\overrides.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\overrides.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\records.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\records.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\records.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\records.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\setup.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\setup.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\setup_common.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\setup_common.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\shape_base.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\shape_base.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\shape_base.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\shape_base.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\__init__.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\__init__.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\core\tests\~_pycache__
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\_locales.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\_locales.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\data\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\core\tests\~ata
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\examples\cython\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\core\tests\examples\~ython
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\examples\limited_api\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\core\tests\examples\~imited_api
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test__exceptions.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test__exceptions.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_abc.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_abc.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_api.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_api.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_argparse.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_argparse.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_array_coercion.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_array_coercion.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_arraymethod.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_arraymethod.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_arrayprint.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_arrayprint.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_casting_unittests.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_casting_unittests.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_conversion_utils.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_conversion_utils.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_cpu_dispatcher.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_cpu_dispatcher.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_cpu_features.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_cpu_features.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_custom_dtypes.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_custom_dtypes.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_cython.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_cython.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_datetime.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_datetime.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_defchararray.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_defchararray.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_deprecations.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_deprecations.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_dlpack.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_dlpack.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_dtype.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_dtype.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_einsum.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_einsum.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_errstate.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_errstate.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_extint128.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_extint128.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_function_base.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_function_base.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_getlimits.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_getlimits.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_half.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_half.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_hashtable.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_hashtable.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_indexerrors.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_indexerrors.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_indexing.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_indexing.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_item_selection.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_item_selection.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_limited_api.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_limited_api.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_longdouble.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_longdouble.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_machar.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_machar.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_mem_overlap.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_mem_overlap.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_mem_policy.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_mem_policy.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_memmap.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_memmap.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_multiarray.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_multiarray.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_nditer.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_nditer.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_numeric.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_numeric.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_numerictypes.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_numerictypes.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_overrides.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_overrides.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_print.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_print.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_protocols.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_protocols.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_records.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_records.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_regression.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_regression.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_scalar_ctors.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_scalar_ctors.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_scalar_methods.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_scalar_methods.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_scalarbuffer.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_scalarbuffer.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_scalarinherit.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_scalarinherit.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_scalarmath.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_scalarmath.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_scalarprint.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_scalarprint.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_shape_base.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_shape_base.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_simd.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_simd.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_simd_module.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_simd_module.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_ufunc.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_ufunc.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_umath.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_umath.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_umath_accuracy.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_umath_accuracy.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_umath_complex.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_umath_complex.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\tests\test_unicode.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\tests\test_unicode.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\umath.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\umath.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\core\umath_tests.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\core\umath_tests.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\ctypeslib.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\ctypeslib.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\ctypeslib.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\ctypeslib.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\__config__.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\__config__.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\__init__.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\__init__.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\__init__.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\__init__.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\__pycache__\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\distutils\~_pycache__
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\_shell_utils.py
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\44778\\anaconda3\\Lib\\site-packages\\numpy\\core\\_multiarray_tests.cp39-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\_shell_utils.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\armccompiler.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\armccompiler.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\ccompiler.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\ccompiler.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\ccompiler_opt.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\ccompiler_opt.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\checks\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\distutils\~hecks
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\command\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\distutils\~ommand
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\conv_template.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\conv_template.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\core.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\core.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\cpuinfo.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\cpuinfo.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\exec_command.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\exec_command.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\extension.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\extension.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\fcompiler\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\distutils\~compiler
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\from_template.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\from_template.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\intelccompiler.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\intelccompiler.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\lib2def.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\lib2def.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\line_endings.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\line_endings.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\log.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\log.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\mingw32ccompiler.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\mingw32ccompiler.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\mingw\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\distutils\~ingw
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\misc_util.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\misc_util.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\msvc9compiler.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\msvc9compiler.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\msvccompiler.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\msvccompiler.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\npy_pkg_config.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\npy_pkg_config.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\numpy_distribution.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\numpy_distribution.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\pathccompiler.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\pathccompiler.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\setup.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\setup.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\system_info.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\system_info.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\tests\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\distutils\~ests
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\distutils\unixccompiler.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\distutils\unixccompiler.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\doc\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\~oc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\dual.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\dual.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\f2py\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\~2py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\fft\__init__.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\fft\__init__.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\fft\__init__.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\fft\__init__.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\fft\__pycache__\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\fft\~_pycache__
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\fft\_pocketfft.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\fft\_pocketfft.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\fft\_pocketfft.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\fft\_pocketfft.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\fft\helper.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\fft\helper.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\fft\helper.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\fft\helper.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\fft\setup.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\fft\setup.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\fft\tests\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\fft\~ests
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\lib\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\~ib
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\license.txt
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\license.txt
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\linalg\__init__.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\linalg\__init__.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\linalg\__init__.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\linalg\__init__.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\linalg\__pycache__\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\linalg\~_pycache__
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\linalg\linalg.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\linalg\linalg.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\linalg\linalg.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\linalg\linalg.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\linalg\setup.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\linalg\setup.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\linalg\tests\__init__.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\linalg\tests\__init__.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\linalg\tests\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\linalg\tests\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\linalg\tests\__pycache__\test_deprecations.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\linalg\tests\__pycache__\test_deprecations.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\linalg\tests\__pycache__\test_linalg.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\linalg\tests\__pycache__\test_linalg.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\linalg\tests\__pycache__\test_regression.cpython-39.pyc
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\linalg\tests\__pycache__\test_regression.cpython-39.pyc
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\linalg\tests\test_deprecations.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\linalg\tests\test_deprecations.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\linalg\tests\test_linalg.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\linalg\tests\test_linalg.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\linalg\tests\test_regression.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\linalg\tests\test_regression.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\ma\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\~a
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\matlib.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\matlib.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\matrixlib\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\~atrixlib
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\polynomial\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\~olynomial
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\py.typed
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\py.typed
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\random\__init__.pxd
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\random\__init__.pxd
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\random\__init__.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\random\__init__.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\random\__init__.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\random\__init__.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\random\__pycache__\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\random\~_pycache__
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\random\_bounded_integers.pxd
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\random\_bounded_integers.pxd
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\random\_common.pxd
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\random\_common.pxd
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\random\_examples\cffi\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\random\_examples\~ffi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\random\_examples\cython\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\random\_examples\~ython
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\random\_examples\numba\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\random\_examples\~umba
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\random\_generator.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\random\_generator.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\random\_mt19937.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\random\_mt19937.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\random\_pcg64.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\random\_pcg64.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\random\_philox.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\random\_philox.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\random\_pickle.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\random\_pickle.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\random\_sfc64.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\random\_sfc64.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\random\bit_generator.pxd
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\random\bit_generator.pxd
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\random\bit_generator.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\random\bit_generator.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\random\c_distributions.pxd
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\random\c_distributions.pxd
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\random\lib\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\random\~ib
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\random\mtrand.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\random\mtrand.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\random\setup.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\random\setup.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\random\tests\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\random\~ests
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\setup.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\setup.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\testing\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\~esting
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\tests\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\~ests
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\__init__.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\__init__.py
# ...
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\fail\ndarray_misc.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\fail\nditer.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\fail\nditer.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\fail\nested_sequence.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\fail\nested_sequence.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\fail\npyio.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\fail\npyio.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\fail\numerictypes.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\fail\numerictypes.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\fail\random.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\fail\random.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\fail\rec.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\fail\rec.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\fail\scalars.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\fail\scalars.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\fail\shape_base.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\fail\shape_base.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\fail\stride_tricks.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\fail\stride_tricks.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\fail\testing.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\fail\testing.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\fail\twodim_base.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\fail\twodim_base.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\fail\type_check.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\fail\type_check.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\fail\ufunc_config.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\fail\ufunc_config.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\fail\ufunclike.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\fail\ufunclike.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\fail\ufuncs.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\fail\ufuncs.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\fail\warnings_and_errors.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\fail\warnings_and_errors.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\misc\extended_precision.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\misc\extended_precision.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\mypy.ini
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\mypy.ini
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\pass\
#    from C:\Users\44778\anaconda3\Lib\site-packages\numpy\typing\tests\data\~ass
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\arithmetic.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\arithmetic.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\array_constructors.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\array_constructors.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\arraypad.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\arraypad.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\arrayprint.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\arrayprint.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\arraysetops.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\arraysetops.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\arrayterator.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\arrayterator.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\bitwise_ops.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\bitwise_ops.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\char.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\char.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\chararray.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\chararray.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\comparisons.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\comparisons.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\constants.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\constants.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\ctypeslib.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\ctypeslib.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\datasource.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\datasource.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\dtype.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\dtype.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\einsumfunc.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\einsumfunc.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\fft.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\fft.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\flatiter.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\flatiter.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\fromnumeric.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\fromnumeric.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\getlimits.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\getlimits.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\histograms.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\histograms.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\index_tricks.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\index_tricks.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\lib_function_base.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\lib_function_base.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\lib_polynomial.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\lib_polynomial.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\lib_utils.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\lib_utils.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\lib_version.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\lib_version.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\linalg.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\linalg.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\matrix.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\matrix.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\memmap.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\memmap.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\mod.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\mod.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\modules.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\modules.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\multiarray.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\multiarray.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\nbit_base_example.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\nbit_base_example.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\ndarray_conversion.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\ndarray_conversion.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\ndarray_misc.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\ndarray_misc.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\ndarray_shape_manipulation.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\ndarray_shape_manipulation.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\nditer.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\nditer.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\nested_sequence.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\nested_sequence.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\npyio.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\npyio.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\numeric.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\numeric.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\numerictypes.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\numerictypes.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\random.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\random.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\rec.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\rec.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\scalars.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\scalars.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\shape_base.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\shape_base.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\stride_tricks.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\stride_tricks.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\testing.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\testing.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\twodim_base.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\twodim_base.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\type_check.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\type_check.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\ufunc_config.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\ufunc_config.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\ufunclike.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\ufunclike.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\ufuncs.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\ufuncs.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\version.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\version.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\data\reveal\warnings_and_errors.pyi
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\data\reveal\warnings_and_errors.pyi
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\test_generic_alias.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\test_generic_alias.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\test_isfile.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\test_isfile.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\test_runtime.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\test_runtime.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\typing\tests\test_typing.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\typing\tests\test_typing.py
#   Moving to c:\users\44778\anaconda3\lib\site-packages\numpy\version.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-hh_7ksjk\version.py
#   Moving to c:\users\44778\anaconda3\scripts\f2py-script.py
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-g01uwnb5\f2py-script.py
#   Moving to c:\users\44778\anaconda3\scripts\f2py.exe
#    from C:\Users\44778\AppData\Local\Temp\pip-uninstall-g01uwnb5\f2py.exe

# %%
#from pyclustertend import hopkins
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 from pyclustertend import hopkins
#
# ModuleNotFoundError: No module named 'pyclustertend'

# %%
#X = df.copy()

# %%
#hopkins(X, X.shape[0])

# %% [markdown]
# ## Dendrogram

# %% [markdown]
# - Tree-like hierarchical representation of clusters is called a dendrogram.
# - It illustrates the arrangement of the clusters produced by the corresponding analyses.

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

# %% [markdown]
# dendogram tanimlamak icin linkage belirlemek gerekiyor

# %%
# dendrogram()

# %% [markdown]
# **“linkage” parameter: (default= “ward”)**
#
#   {‘ward’, ‘complete’, ‘average’, ‘single’}
#
# Which linkage criterion to use. The linkage criterion determines which distance to use between sets of observation.
# -	Ward minimizes the variance of the clusters being merged.
# -	Average uses the average of the distances of each observation of the two sets.
# -	Complete or maximum linkage uses the maximum distances between all observations of the two sets.
# -	Single uses the minimum of the distances between all observations of the two sets.

# %%
hc_ward = linkage(y = X, method = "ward")
hc_complete = linkage(X, "complete")
hc_average = linkage(X, "average")
hc_single = linkage(X, "single")

# %%
plt.figure(figsize = (20,8))
plt.title("Dendrogram")
plt.xlabel("Observations")
plt.ylabel("Distance")
dendrogram(hc_ward, leaf_font_size = 10);

# %% [markdown]
# burada 2 cluster olmus ama normalde 3 kume oldugunu biliyoruz

# %%
plt.figure(figsize = (20,12))

plt.subplot(221)
plt.title("Ward")
plt.xlabel("Observations")
plt.ylabel("Distance")
dendrogram(hc_ward, leaf_font_size = 10)

plt.subplot(222)
plt.title("Complete")
plt.xlabel("Observations")
plt.ylabel("Distance")
dendrogram(hc_complete, leaf_font_size = 10)

plt.subplot(223)
plt.title("Average")
plt.xlabel("Observations")
plt.ylabel("Distance")
dendrogram(hc_average, leaf_font_size = 10)

plt.subplot(224)
plt.title("Single")
plt.xlabel("Observations")
plt.ylabel("Distance")
dendrogram(hc_single, leaf_font_size = 10);

# %%
plt.figure(figsize = (20,12))

plt.subplot(221)
plt.title("Ward")
plt.xlabel("Observations")
plt.ylabel("Distance")
dendrogram(hc_ward, leaf_font_size = 10, truncate_mode='lastp', p=10)

plt.subplot(222)
plt.title("Complete")
plt.xlabel("Observations")
plt.ylabel("Distance")
dendrogram(hc_complete, leaf_font_size = 10, truncate_mode='lastp', p=10)

plt.subplot(223)
plt.title("Average")
plt.xlabel("Observations")
plt.ylabel("Distance")
dendrogram(hc_average, leaf_font_size = 10, truncate_mode='lastp', p=10)

plt.subplot(224)
plt.title("Single")
plt.xlabel("Observations")
plt.ylabel("Distance")
dendrogram(hc_single, leaf_font_size = 10, truncate_mode='lastp', p=10);

# %% [markdown]
# ## Hierarchical Clustering (Agglomerative)

# %% [markdown]
# - Ideal clustering is characterised by minimal intra cluster distance and maximal inter cluster distance

# %%
from sklearn.cluster import AgglomerativeClustering

# %% [markdown]
# ### S(Silhouette) Score

# %% [markdown]
# - If the ground truth labels are not known, evaluation must be performed using the model itself. (One of the evaluation method is Silhouette Coefficient)
# - A higher Silhouette Coefficient score relates to a model with better defined clusters.
# - a :The mean distance between a sample and all other points in the same class.
#   b: The mean distance between a sample and all other points in the next nearest cluster.
#
# s = (b-a) / max(a,b)

# %%
from sklearn.metrics import silhouette_score

# %%
K = range(2,10)

for k in K:
    model = AgglomerativeClustering(n_clusters = k)
    model.fit_predict(X)
    print(f'Silhouette Score for {k} clusters: {silhouette_score(X, model.labels_)}')

# %%
model1 = AgglomerativeClustering(n_clusters=3, affinity = "euclidean", linkage = "ward")
model1.fit_predict(X)

# %% [markdown]
# inertia = ssd sum squared distance

# %%
model1.labels_

# %%
plt.scatter(X["petal_length"], X["petal_width"], c = model1.labels_, cmap = "viridis", alpha =0.7)

# %%
clusters = model1.labels_

# %%
labels = pd.read_csv("label.csv")
labels

# %%
X["predicted_clusters"] = clusters
X["labels"] = labels
X

# %%
ct = pd.crosstab(X["predicted_clusters"], X["labels"])
ct

# %% [markdown]
# ## ARI Score
#
# - The Adjusted Rand Index computes a similarity measure between two clusterings by considering all pairs of samples and counting pairs that are assigned in the same or different clusters in the predicted and true clusterings.
# - The value of ARI indicates no good clustering if it is close to zero or negative, and a good cluster if it is close to 1.

# %%
from sklearn.metrics.cluster import adjusted_rand_score

# %%
adjusted_rand_score(X.labels, X.predicted_clusters)

# %% [markdown]
# ## Visualization Clusters

# %%
X_labels = X.labels.map({"versicolor":0, "setosa":1,"virginica":2})
X_labels

# %% [markdown]
# mapping yapma sebebimiz cateogirinin ne oldugunu anlamak icin numaralandirma

# %%
plt.figure(figsize = (20,6))

plt.subplot(121)
plt.scatter(X["sepal_length"], X["sepal_width"], c = X_labels, cmap = "viridis", alpha=0.7, s=100)
plt.title("Actual")

plt.subplot(122)
plt.scatter(X["sepal_length"], X["sepal_width"], c = X.predicted_clusters, cmap = "viridis", alpha=0.7, s=100)
plt.title("Predicted");

# %%
plt.figure(figsize = (20,6))

plt.subplot(121)
plt.scatter(X["sepal_width"], X["petal_length"], c = X_labels, cmap = "viridis", alpha=0.7, s=100)
plt.title("Actual")

plt.subplot(122)
plt.scatter(X["sepal_width"], X["petal_length"], c = X.predicted_clusters, cmap = "viridis", alpha=0.7, s=100)
plt.title("Predicted");

# %% [markdown]
# ## Remodeling according to discriminating features

# %% [markdown]
# bazi featurelari cikarip tekrar modelleme

# %%
X.head()

# %%
clus_pred = X.iloc[:, [0, 1, 2, 3, 5]].groupby("labels").mean().T
clus_pred

# %% [markdown]
# sepal width isleri karistiyior mnavi cizgi

# %%
sns.lineplot(data = clus_pred)

# %%
plt.figure(figsize = (20,6))

plt.subplot(141)
sns.boxplot(y = "sepal_length", x = "labels", data = X)

plt.subplot(142)
sns.boxplot(y = "sepal_width", x = "labels", data = X)

plt.subplot(143)
sns.boxplot(y = "petal_length", x = "labels", data = X)

plt.subplot(144)
sns.boxplot(y = "petal_width", x = "labels", data = X)

# %%
X2 = X.iloc[:, [2,3]]
X2

# %% [markdown]
# ### Hopkins Test

# %%
hopkins(X2, X2.shape[0])
#yuksek bir skor
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 hopkins(X2, X2.shape[0])
#
# NameError: name 'hopkins' is not defined

# %% [markdown]
# ### Dendrogram

# %%
hc_ward = linkage(y = X2, method = "ward")
hc_complete = linkage(X2, "complete")
hc_average = linkage(X2, "average")
hc_single = linkage(X2, "single")

# %%
plt.figure(figsize = (20,12))

plt.subplot(221)
plt.title("Ward")
plt.xlabel("Observations")
plt.ylabel("Distance")
dendrogram(hc_ward, leaf_font_size = 10, truncate_mode='lastp', p=10)

plt.subplot(222)
plt.title("Complete")
plt.xlabel("Observations")
plt.ylabel("Distance")
dendrogram(hc_complete, leaf_font_size = 10, truncate_mode='lastp', p=10)

plt.subplot(223)
plt.title("Average")
plt.xlabel("Observations")
plt.ylabel("Distance")
dendrogram(hc_average, leaf_font_size = 10, truncate_mode='lastp', p=10)

plt.subplot(224)
plt.title("Single")
plt.xlabel("Observations")
plt.ylabel("Distance")
dendrogram(hc_single, leaf_font_size = 10, truncate_mode='lastp', p=10);

# %% [markdown]
# ### S(Silhouette) Score

# %%
K = range(2,10)

for k in K:
    model = AgglomerativeClustering(n_clusters = k)
    model.fit_predict(X2)
    print(f'Silhouette Score for {k} clusters: {silhouette_score(X2, model.labels_)}')
# Out:
# Silhouette Score for 2 clusters: 0.7669465622770762
# Silhouette Score for 3 clusters: 0.6573949269287823
# Silhouette Score for 4 clusters: 0.5895284480910935
# Silhouette Score for 5 clusters: 0.5781917218437669
# Silhouette Score for 6 clusters: 0.5747380906148477
# Silhouette Score for 7 clusters: 0.5830818097709548
# Silhouette Score for 8 clusters: 0.5678904784921739
# Silhouette Score for 9 clusters: 0.5469910001848306

# %% [markdown]
# ## Final model

# %%
final_model = AgglomerativeClustering(n_clusters=3, affinity = "euclidean", linkage = "complete")
clusters = final_model.fit_predict(X2)

# %%
X2["predicted_clusters"] = clusters
X2["labels"] = labels
X2
# Out:
#      petal_length  petal_width  predicted_clusters     labels
# 0             1.4          0.2                   2     setosa
# 1             1.4          0.2                   2     setosa
# 2             1.3          0.2                   2     setosa
# 3             1.5          0.2                   2     setosa
# 4             1.4          0.2                   2     setosa
# ..            ...          ...                 ...        ...
# 145           5.2          2.3                   0  virginica
# 146           5.0          1.9                   0  virginica
# 147           5.2          2.0                   0  virginica
# 148           5.4          2.3                   0  virginica
# 149           5.1          1.8                   0  virginica
#
# [150 rows x 4 columns]

# %%
X2_ct = pd.crosstab(X2["predicted_clusters"], X2["labels"])
X2_ct
# Out:
# labels              setosa  versicolor  virginica
# predicted_clusters
# 0                        0           5         49
# 1                        0          45          1
# 2                       50           0          0

# %%
ct
# Out:
# labels              setosa  versicolor  virginica
# predicted_clusters
# 0                        0          49         15
# 1                       50           0          0
# 2                        0           1         35

# %%
X2_labels = X2.labels.map({"versicolor":0, "setosa":1,"virginica":2})
X2_labels
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: labels, Length: 150, dtype: int64

# %%
plt.figure(figsize = (20,6))

plt.subplot(121)
plt.scatter(X2["petal_length"], X2["petal_width"], c = X2_labels, cmap = "viridis", alpha=0.7, s=100)
plt.title("Actual")

plt.subplot(122)
plt.scatter(X2["petal_length"], X2["petal_width"], c = X2.predicted_clusters, cmap = "viridis", alpha=0.7, s=100)
plt.title("Predicted");

# %% [markdown]
# ### ARI Score

# %%
adjusted_rand_score(X2.labels, X2.predicted_clusters)
# Out:
# 0.8857921001989628

# %% [markdown]
# ## Prediction cluster of new data

# %%
new_data = [[1.7, 0.2], [2.3, 0.5]]

# %%
final_model.predict(new_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/ML/Documents/ABD2021/Course/Lectures/2. Inclass Notebooks/ML-18/ML-18 (Hierarchical-Clustering-iris).ipynb Cell 73' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/ML/Documents/ABD2021/Course/Lectures/2.%20Inclass%20Notebooks/ML-18/ML-18%20%28Hierarchical-Clustering-iris%29.ipynb#ch0000071?line=0'>1</a> final_model.predict(new_data)
#
# AttributeError: 'AgglomerativeClustering' object has no attribute 'predict'

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]
