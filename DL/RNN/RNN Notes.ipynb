# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Eğer işlenen videodaki hareketlerin ya da  tespit edilecek şeylerin sırası önemli ise, RNN in Computer visionda da kullanıladığını görebilirsini (Orion Hodja)

# %% [raw]
# Time series data = zamana bagli data

# %% [raw]
# ML'deki assumption "i.i.d" yani "independent and identically distributed". Fakat sequential data'da bu assumption saglanmiyor o yuzden sequential data farkli yaklasimlar gerektiriyor

# %% [raw]
# Whenever the points in the dataset are dependent on the other points in the dataset, the data is said to be Sequantial Data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Bir squence var, sıralamanın önemli olması, gibi hususlar öne çıkıyorsa RNN öne çıkar. (Orion)

# %% [raw]
# Bu RNN de çok gariplik olacak target aynı zamanda bir sonraki seri için feature olacak

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# The network is called "recurrent" because it performs the same operation in each actiive square.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Gradient Exploding >> cozum clipping

# %% [raw]
# Vanishing Gradient >> cozum
# 1) Weight initialization
# 2) Batch normalization
# 3) Using activation function apart from "Sigmoid" and "tanh (ReLU)"
# 4) Using LSTM and GRU

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# RNN

# %% [markdown]
# ![1_xn5kA92_J5KLaKcP7BMRLA.gif](attachment:1_xn5kA92_J5KLaKcP7BMRLA.gif)

# %% [markdown]
# LSTM

# %% [markdown]
# ![lstm.gif](attachment:lstm.gif)

# %% [markdown]
# GRU

# %% [markdown]
# ![gru.gif](attachment:gru.gif)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
